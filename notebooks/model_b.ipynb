# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\afiq zafry\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.1.2)
# Requirement already satisfied: numpy in c:\users\afiq zafry\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xgboost) (2.2.5)
# Requirement already satisfied: scipy in c:\users\afiq zafry\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xgboost) (1.15.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv("../data/preprocessed_df.csv")

# %%
# Target columns
target_cols = [
    "risk_category_low",
    "risk_category_medium",
    "risk_category_high"
]

# Features
X = df.drop(columns=target_cols)

# Convert one-hot to label
y = df[target_cols].idxmax(axis=1)
y = y.str.replace("risk_category_", "")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       2 target_cols = [
#       3     "risk_category_low",
#       4     "risk_category_medium",
#       5     "risk_category_high"
#       6 ]
#       8 # Features
# ----> 9 X = df.drop(columns=target_cols)
#      11 # Convert one-hot to label
#      12 y = df[target_cols].idxmax(axis=1)
#
# NameError: name 'df' is not defined

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

print(dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_))))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y_encoded,
    test_size=0.2,
    random_state=42,
    stratify=y_encoded
)

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(
    objective="multi:softprob",
    num_class=3,
    n_estimators=300,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric="mlogloss",
    random_state=42,
    n_jobs=-1
)

xgb_model.fit(X_train, y_train)

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = xgb_model.predict(X_test)

print("Classification Report:")
print(classification_report(
    y_test,
    y_pred,
    target_names=label_encoder.classes_
))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
